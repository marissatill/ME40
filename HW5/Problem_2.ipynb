# %% [markdown]
# ## ME40: Dimensional & Data Analyses in Engineering
# ### HW 5 - Monday November 12th, 2025
# #### Marissa Till

# %% [markdown]
# ### Problem 2 - Polynomial fits
# ##### (This was done in Python rather than MATLAB)

# %% [markdown]
# Let’s assume that you have a program/code/script do a multi-linear fit. It is a completely “black box”. The only thing you know is that it takes a series of input values x$_i$, y$_i$, z$_i$, one vector of output/target values t$_i$, and it returns the coefficients 𝑎, 𝑏, 𝑐, 𝑑 for a linear fit of the form 𝑡 = 𝑎x + 𝑏𝑦 + 𝑐𝑧 + 𝑑.
#
# 1. How do you use this software to perform a polynomial fit of the form 𝑡 = 𝛼x$^3$ + 𝛽x$^2$ + 𝛾x + 𝛿 ?
#
# Note: I am not asking for you to write a linear system. In fact, there should be very limited math!

# %% [markdown]
# ### Answer
#
# This software outputs the same variables a, b, c, d, which in our case will be a = 𝛼, b = 𝛽, c = 𝛾, and d = 𝛿. The only thing we can change for this 'black box' program/code/script is the input.
#
# The target output vector does not change. It is a linear combination of the input terms t$_i$ = 𝑡.
#
# The input values can be changed to match the polynomial terms. The software will still perform a linear fit in its coefficients. The input values will be x$_i$ = x$^3$, y$_i$ = x$^2$, and z$_i$ = x
#
# This method will perform a polynomial fit without changing the target output, simply expressing the polynomial as a linear combination of transformed input terms (multiplication of each term in the series).
